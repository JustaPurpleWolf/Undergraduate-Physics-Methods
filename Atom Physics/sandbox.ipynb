# %%
import ElecSus
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import ElecSus
#
# ModuleNotFoundError: No module named 'ElecSus'

# %%
from elecsus import elecsus_gui
elecsus_gui.start()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from elecsus import elecsus_gui
#       2 elecsus_gui.start()
#
# ModuleNotFoundError: No module named 'elecsus'
