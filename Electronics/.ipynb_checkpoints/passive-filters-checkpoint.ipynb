# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
R, C = 10 * 1E3, 4.7 * 1E-9 # Ohms, Farads
alpha = 1 / (R * C) # Hz

omega = 1E9 # Hz
A_in = 14.4 # V

T = 1/omega
#H_V = 1 / np.sqrt(1 + (omega / alpha)**2)
H_V = 1 / np.sqrt(1 + (omega / alpha)**2)
phi = np.arctan(-omega / alpha)

t = np.linspace(-T, T, 1000)
V_in, V_out = 0.5*A_in*np.sin(2*np.pi*omega * t), 0.5*A_in*H_V*np.sin(2*np.pi*omega*t - 2*np.pi*phi)
a_in, a_out = np.max(V_in)-np.min(V_in), np.max(V_out)-np.min(V_in)

print(f'A_in: {a_in} V')
print(f'A_out: {a_out} V')
# Out:
# A_in: 14.399982199131804 V
# A_out: 7.200144290429954 V

# %%
fig, ax = plt.subplots()
ax.plot(t, V_in, label="V_in", color = "orange")
ax.plot(t, V_out, label="V_out", color = "blue")
ax.set(xlabel="t", ylabel="V")
ax.grid(True)
plt.legend()
plt.show()

# %%
key_words = ["low_pass", "high_pass", "gaussian"]
dfs = [pd.read_csv("20250911_C1_SINE.csv"), pd.read_csv("20250911_C1_SINE.csv")]

# %%
df = pd.read_csv("20250911_C1_SINE.csv") 
df_Hv = (df["V_out[V]"] - df["noise[V]"]) / df["V_in[V]"]
df_phase = -2*np.pi*1E-6*df["lag[us]"]

delta_in = 0.1
delta_out = 0.1
delta_noise = 0.1
delta_df_Hv = abs((df["V_out[V]"] - df["noise[V]"]) / (df["V_in[V]"]**2) +  1/ df["V_in[V]"])

# %%
Omega = 2*np.pi*np.linspace(1, 1E7, int(1E6))
H_V_dB = 20 * np.log10(1 / np.sqrt(1 + (Omega / alpha)**2)) #low-pass filter
#H_V_dB = 20 * np.log10(1 / np.sqrt(1 + (alpha / Omega)**2)) #high-pass filter


phase = np.arctan(-Omega/alpha)
log_omega = np.log10(f)

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(2,1,1)
bx = fig.add_subplot(2,1,2)

ax.plot(Omega, H_V_dB, color="k", linewidth = 1)
ax.errorbar(2*np.pi*df["f_in[Hz]"], 20 * np.log10(df_Hv), yerr = 20 * np.log10(delta_df_Hv), fmt='o', capsize=5, ecolor='red')
ax.axvline(alpha, color="r", ls="--", label=f"$\\alpha$", alpha = 0.5)
ax.set(xlabel="$\omega$", ylabel="$H_{V,dB}$")

bx.plot(Omega, phase, color = "k", linewidth = 1)
bx.scatter(2*np.pi*df["f_in[Hz]"], df_phase*df["f_in[Hz]"], s = 10, marker="o", color="b")
bx.axvline(alpha, color="r", ls="--", label=f"$\\alpha$", alpha = 0.5)
bx.set(xlabel="$\omega$", ylabel="$\phi$")

ax.set_xscale('log'), bx.set_xscale('log')
ax.legend(), bx.legend()
ax.grid(), bx.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 14
#      11 bx = fig.add_subplot(2,1,2)
#      13 ax.plot(Omega, H_V_dB, color="k", linewidth = 1)
# ---> 14 ax.errorbar(2*np.pi*df["f_in[Hz]"], 20 * np.log10(df_Hv), yerr = 20 * np.log10(delta_df_Hv), fmt='o', capsize=5, ecolor='red')
#      15 ax.axvline(alpha, color="r", ls="--", label=f"$\\alpha$", alpha = 0.5)
#      16 ax.set(xlabel="$\omega$", ylabel="$H_{V,dB}$")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:3797, in Axes.errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, **kwargs)
#    3794 res = np.zeros(err.shape, dtype=bool)  # Default in case of nan
#    3795 if np.any(np.less(err, -err, out=res, where=(err == err))):
#    3796     # like err<0, but also works for timedelta and nan.
# -> 3797     raise ValueError(
#    3798         f"'{dep_axis}err' must not contain negative values")
#    3799 # This is like
#    3800 #     elow, ehigh = np.broadcast_to(...)
#    3801 #     return dep - elow * ~lolims, dep + ehigh * ~uplims
#    3802 # except that broadcast_to would strip units.
#    3803 low, high = dep + np.vstack([-(1 - lolims), 1 - uplims]) * err
#
# ValueError: 'yerr' must not contain negative values

# %%
'''weird filter'''
R1, R2, C = 220, 100, 0.68 * 1E-6 # Ohms, Farads
omega = 1E9 # Hz
A_in = 14.4 # V

T = 1/omega
z = R1*R2*omega*C-1/(omega*C)
H_V = np.sqrt((2*R2*(R1+2*R2)+z**2)**2+(z**2)*(R1**2)) / ((R1+2*R2)**2 + z**2)
phi = np.arctan(z*R1/(2*R2*(R1+2*R2)))

t = np.linspace(-T, T, 1000)
V_in, V_out = 0.5*A_in*np.sin(2*np.pi*omega * t), 0.5*A_in*H_V*np.sin(2*np.pi*omega*t - 2*np.pi*phi)
a_in, a_out = np.max(V_in)-np.min(V_in), np.max(V_out)-np.min(V_in)

print(f'A_in: {a_in} V')
print(f'A_out: {a_out} V')

# %%
df = pd.read_csv("20250911_C3_SINE.csv")
df_Hv = (df["V_out[V]"] - df["noise[V]"]) / df["V_in[V]"]

# %%
f = np.linspace(1, 1E7, int(1E6))
Omega = f*2*np.pi
Z = R1*R2*Omega*C-1/(Omega*C)
H_V_dB = 20 * np.log10(np.sqrt((2*R2*(R1+2*R2)+Z**2)**2+(Z**2)*(R1**2)) / ((R1+2*R2)**2 + Z**2)) #band-reject filter
log_omega = np.log10(f)

fig, ax = plt.subplots()
ax.plot(log_omega, H_V_dB, color="k", alpha=0.8)
ax.scatter(np.log10(df["f_in[Hz]"]), 20 * np.log10(df_Hv), s = 10, marker="o", color="b")

ax.set(xlabel="$log(\omega)$", ylabel="$H_{V,dB}$")

plt.grid()
plt.show()
